# %% [markdown]
# # HAPPINESS REPORT

# %% [markdown]
# # INTRODUCTION
# Happiness is the most important aspects in our life. The most challenging work is to stay happy in today's world.
# In this entire data i have worked to inspect what are the factors which make a country's people happy.
# In this project i have worked on various factors to make a country most suitable place to stay happy.
# In brief i have tried to predict and summarize which countries rank highest in terms of happiness and which aspects there happiness depends on.

# %%
# importing the necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_validate
import warnings
warnings.filterwarnings('ignore')
import pickle

# %%
# loading the data set for top countries

happy_2015 = pd.read_csv('happiness_score_dataset.csv')
happy_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
# loading the data set for bottom countries

happy_2015.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726

# %% [markdown]
# ##### The above dataset shows us the top and bottom 5 countires keeping all the factors like GDP per capita, family,health,freedom,trust,generosity and dystopia residual into consideration.

# %%
happy_2015.shape
# Out:
# (158, 12)

# %% [markdown]
# #### The above statment shows that there is altogether 158 rows and 12 columns in entire data set.

# %%
# lets find out is there any null values in all the cloumns

pd.set_option('display.max_rows',None)

# %%
happy_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %% [markdown]
# #### The above statement help us to know that there is no null values in all the 12 columns. There is 9 columns which is float type, 2 columns is in object type and 1 column is in integer type.

# %%
# lets find out the mean, counts, standard deviation and outliers

happy_2015.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# 50%                    0.910245    1.029510                  0.696705
# 75%                    1.158448    1.214405                  0.811013
# max                    1.690420    1.402230                  1.025250
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  158.000000                     158.000000  158.000000
# mean     0.428615                       0.143422    0.237296
# std      0.150693                       0.120034    0.126685
# min      0.000000                       0.000000    0.000000
# 25%      0.328330                       0.061675    0.150553
# 50%      0.435515                       0.107220    0.216130
# 75%      0.549092                       0.180255    0.309883
# max      0.669730                       0.551910    0.795880
#
#        Dystopia Residual
# count         158.000000
# mean            2.098977
# std             0.553550
# min             0.328580
# 25%             1.759410
# 50%             2.095415
# 75%             2.462415
# max             3.602140

# %% [markdown]
# #### The above table help us to know is there any missing values in dataset. It also help us to know the mean and standard diviation from the above table.The difference between mean and median(50%) help us to understand is there any outliers in dataset.As there is hardly any difference between mean and median so there is no outliers in dataset.

# %%
# Correlation in table format

corr_mat = happy_2015.corr()
corr_mat
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# Standard Error                       1.000000                 -0.217651
# Economy (GDP per Capita)            -0.217651                  1.000000
# Family                              -0.120728                  0.645299
# Health (Life Expectancy)            -0.310287                  0.816478
# Freedom                             -0.129773                  0.370300
# Trust (Government Corruption)       -0.178325                  0.307885
# Generosity                          -0.088439                 -0.010465
# Dystopia Residual                    0.083981                  0.040059
#
#                                  Family  Health (Life Expectancy)   Freedom  \
# Happiness Rank                -0.733644                 -0.735613 -0.556886
# Happiness Score                0.740605                  0.724200  0.568211
# Standard Error                -0.120728                 -0.310287 -0.129773
# Economy (GDP per Capita)       0.645299                  0.816478  0.370300
# Family                         1.000000                  0.531104  0.441518
# Health (Life Expectancy)       0.531104                  1.000000  0.360477
# Freedom                        0.441518                  0.360477  1.000000
# Trust (Government Corruption)  0.205605                  0.248335  0.493524
# Generosity                     0.087513                  0.108335  0.373916
# Dystopia Residual              0.148117                  0.018979  0.062783
#
#                                Trust (Government Corruption)  Generosity  \
# Happiness Rank                                     -0.372315   -0.160142
# Happiness Score                                     0.395199    0.180319
# Standard Error                                     -0.178325   -0.088439
# Economy (GDP per Capita)                            0.307885   -0.010465
# Family                                              0.205605    0.087513
# Health (Life Expectancy)                            0.248335    0.108335
# Freedom                                             0.493524    0.373916
# Trust (Government Corruption)                       1.000000    0.276123
# Generosity                                          0.276123    1.000000
# Dystopia Residual                                  -0.033105   -0.101301
#
#                                Dystopia Residual
# Happiness Rank                         -0.521999
# Happiness Score                         0.530474
# Standard Error                          0.083981
# Economy (GDP per Capita)                0.040059
# Family                                  0.148117
# Health (Life Expectancy)                0.018979
# Freedom                                 0.062783
# Trust (Government Corruption)          -0.033105
# Generosity                             -0.101301
# Dystopia Residual                       1.000000

# %%
#Correlation through heat map

plt.figure(figsize = [22,12])
sns.heatmap(corr_mat,annot = True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# #### The above table and heat map helps us to find out how happiness score is inter related to other factors.It is found that factor which affects happiness score the most is Economy(GDP per capita) i.e 78% and the factor which affects the happiness score least is trust(government corruption) i.e 40%

# %% [markdown]
# # EDA - World Happiness Dataset

# %% [markdown]
# ## Top 10 Happiest Countries

# %%
# list of top 10 happy countries

happy_2015_top10 = happy_2015.groupby('Country')['Happiness Score'].max().sort_values(ascending=False).head(10).reset_index()
happy_2015_top10.columns = ['Country','Happiness Score']
happy_2015_top10
# Out:
#        Country  Happiness Score
# 0  Switzerland            7.587
# 1      Iceland            7.561
# 2      Denmark            7.527
# 3       Norway            7.522
# 4       Canada            7.427
# 5      Finland            7.406
# 6  Netherlands            7.378
# 7       Sweden            7.364
# 8  New Zealand            7.286
# 9    Australia            7.284

# %%
# visualize top 10 happiest country through EDA

plt.figure(figsize=(10,7))
sns.barplot(y=happy_2015_top10['Country'], x=happy_2015_top10['Happiness Score'], palette='twilight', orient='h')
plt.title('Top 10 Happiest Country', fontsize=15)
plt.xlabel('Happiness Score', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 8)
# Out:
# (0.0, 8.0)

# %% [markdown]
# #### The above table and barplot help us to know that Switzerland is the happiest country.

# %% [markdown]
# ## Bottom 10 sad countries

# %%
# list of bottom 10 happy countries

happy_2015_bottom10 = happy_2015.groupby('Country')['Happiness Score'].max().sort_values(ascending=False).tail(10).reset_index()
happy_2015_bottom10.columns = ['Country','Happiness Score']
happy_2015_bottom10
# Out:
#         Country  Happiness Score
# 0          Chad            3.667
# 1        Guinea            3.656
# 2   Ivory Coast            3.655
# 3  Burkina Faso            3.587
# 4   Afghanistan            3.575
# 5        Rwanda            3.465
# 6         Benin            3.340
# 7         Syria            3.006
# 8       Burundi            2.905
# 9          Togo            2.839

# %%
# visualize top 10 saddest country through EDA

plt.figure(figsize=(10,7))
sns.barplot(y=happy_2015_bottom10['Country'], x=happy_2015_bottom10['Happiness Score'], palette='twilight', orient='h')
plt.title('Bottom 10 Sad Country', fontsize=15)
plt.xlabel('Happiness Score', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 4)
# Out:
# (0.0, 4.0)

# %% [markdown]
# #### The above table and barplot help us to know that Togo is the lowest happiness score country.

# %% [markdown]
# ### Top 10 Countries With Highest Economy (GDP per Capita)

# %%
# top countries in terms of GDP

happy_2015_gdp_top10 = happy_2015.groupby('Country')['Economy (GDP per Capita)'].max().sort_values(ascending=False).head(10).reset_index()
happy_2015_gdp_top10.columns = ['Country','Economy (GDP per Capita)']
happy_2015_gdp_top10
# Out:
#                 Country  Economy (GDP per Capita)
# 0                 Qatar                   1.69042
# 1            Luxembourg                   1.56391
# 2                Kuwait                   1.55422
# 3             Singapore                   1.52186
# 4                Norway                   1.45900
# 5  United Arab Emirates                   1.42727
# 6           Switzerland                   1.39651
# 7          Saudi Arabia                   1.39541
# 8         United States                   1.39451
# 9             Hong Kong                   1.38604

# %%
# visualization of top 10 countries ,gdp per capita

plt.figure(figsize=(10,7))
sns.barplot(y=happy_2015_gdp_top10['Country'], x=happy_2015_gdp_top10['Economy (GDP per Capita)'], palette='mako', orient='h')
plt.title('Top 10 Countries With Highest GDP', fontsize=15)
plt.xlabel('Economy (GDP per Capita)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 2)
# Out:
# (0.0, 2.0)

# %% [markdown]
# #### The above table and barplot help us to know that Qatar GDP is highest

# %% [markdown]
# ### Top 10 Countries With Lowest GDP Per Capita

# %%
# country with lowest gdp

happy_2015_gdp_bottom10 = happy_2015.groupby('Country')['Economy (GDP per Capita)'].max().sort_values(ascending=False).tail(10).reset_index()
happy_2015_gdp_bottom10.columns = ['Country','Economy (GDP per Capita)']
happy_2015_gdp_bottom10
# Out:
#                     Country  Economy (GDP per Capita)
# 0                  Ethiopia                   0.19073
# 1         Somaliland region                   0.18847
# 2                    Guinea                   0.17417
# 3                Mozambique                   0.08308
# 4  Central African Republic                   0.07850
# 5                   Liberia                   0.07120
# 6                     Niger                   0.06940
# 7                    Malawi                   0.01604
# 8                   Burundi                   0.01530
# 9          Congo (Kinshasa)                   0.00000

# %%
# visualization top 10 lowest GDP

plt.figure(figsize=(10,7))
sns.barplot(y=happy_2015_gdp_bottom10['Country'], x=happy_2015_gdp_bottom10['Economy (GDP per Capita)'], palette='mako', orient='h')
plt.title('Top 10 Countries With Lowest GDP', fontsize=15)
plt.xlabel('Economy (GDP per Capita)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.3)
# Out:
# (0.0, 0.3)

# %% [markdown]
# #### The above table and barplot help us to know that Congo GDP is lowest

# %% [markdown]
# ### Top 10 countries keeping family as a factor of happiness

# %%
# top 10 countries keeping family as a factor of happiness

happy_2015_family_top10 = happy_2015.groupby('Country')['Family'].max().sort_values(ascending=False).head(10).reset_index()
happy_2015_family_top10.columns = ['Country','Family']
happy_2015_family_top10
# Out:
#        Country   Family
# 0      Iceland  1.40223
# 1      Ireland  1.36948
# 2      Denmark  1.36058
# 3  Switzerland  1.34951
# 4   Uzbekistan  1.34043
# 5       Norway  1.33095
# 6       Canada  1.32261
# 7  New Zealand  1.31967
# 8      Finland  1.31826
# 9        Spain  1.31379

# %%
# visualization top 10 countries keeping family as a factor of happiness

plt.figure(figsize=(10,7))
sns.barplot(y=happy_2015_family_top10['Country'], x=happy_2015_family_top10['Family'], palette='inferno', orient='h')
plt.title('Top 10 Countries With Highest Family Social Support', fontsize=15)
plt.xlabel('Family', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 1.5)
# Out:
# (0.0, 1.5)

# %% [markdown]
# #### The above table and barplot help us to know that Iceland have highest family support.

# %% [markdown]
# ### Top 10 Countries With Lowest Family support

# %%
happy_2015_family_bottom10 = happy_2015.groupby('Country')['Family'].max().sort_values(ascending=False).tail(10).reset_index()
happy_2015_family_bottom10.columns = ['Country','Family']
happy_2015_family_bottom10
# Out:
#                     Country   Family
# 0                Bangladesh  0.43106
# 1                   Burundi  0.41587
# 2                  Pakistan  0.41411
# 3                    Malawi  0.41134
# 4                   Georgia  0.38562
# 5                     India  0.38174
# 6                     Benin  0.35386
# 7               Afghanistan  0.30285
# 8                      Togo  0.13995
# 9  Central African Republic  0.00000

# %%
# visualization top 10 lowest family

plt.figure(figsize=(10,7))
sns.barplot(y=happy_2015_family_bottom10['Country'], x=happy_2015_family_bottom10['Family'], palette='inferno', orient='h')
plt.title('Top 10 Countries With Lowest Family Social Support', fontsize=15)
plt.xlabel('Family', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.3)
# Out:
# (0.0, 0.3)

# %% [markdown]
# #### The above table and barplot help us to know that Central African Republic country have lowest family support.

# %% [markdown]
# ### Top 10 Countries With Highest Healthy Life Expectancy

# %%
# Top 10 Countries With Highest Healthy Life Expectancy

happy_2015_health_top10 = happy_2015.groupby('Country')['Health (Life Expectancy)'].max().sort_values(ascending=False).head(10).reset_index()
happy_2015_health_top10.columns = ['Country','Health (Life Expectancy)']
happy_2015_health_top10
# Out:
#        Country  Health (Life Expectancy)
# 0    Singapore                   1.02525
# 1    Hong Kong                   1.01328
# 2        Japan                   0.99111
# 3  South Korea                   0.96538
# 4        Spain                   0.95562
# 5        Italy                   0.95446
# 6      Iceland                   0.94784
# 7       France                   0.94579
# 8  Switzerland                   0.94143
# 9    Australia                   0.93156

# %%
# # visualization top 10 highest family

plt.figure(figsize=(10,7))
sns.barplot(y=happy_2015_health_top10['Country'], x=happy_2015_health_top10['Health (Life Expectancy)'], palette='flare', orient='h')
plt.title('Top 10 Countries With Highest Healthy Life Expectancy', fontsize=15)
plt.xlabel('Health (Life Expectancy)')
plt.ylabel('Country')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)

# %% [markdown]
# #### The above table and barplot help us to know that Singapore country have highest healthy life expectance.

# %% [markdown]
# ### Top 10 Countries With Lowest Healthy Life Expectancy - 2015

# %%
# Top 10 Countries With Lowest Healthy Life Expectancy

happy_2015_health_bottom10 = happy_2015.groupby('Country')['Health (Life Expectancy)'].max().sort_values(ascending=False).tail(10).reset_index()
happy_2015_health_bottom10.columns = ['Country','Health (Life Expectancy)']
happy_2015_health_bottom10
# Out:
#                     Country  Health (Life Expectancy)
# 0                   Nigeria                   0.16007
# 1               Ivory Coast                   0.15185
# 2                      Chad                   0.15010
# 3          Congo (Kinshasa)                   0.09806
# 4                Mozambique                   0.09131
# 5                   Lesotho                   0.07612
# 6                 Swaziland                   0.07566
# 7  Central African Republic                   0.06699
# 8                  Botswana                   0.04776
# 9              Sierra Leone                   0.00000

# %%
# visualization bottom 10 lowest family

plt.figure(figsize=(10,7))
sns.barplot(y=happy_2015_health_bottom10['Country'], x=happy_2015_health_bottom10['Health (Life Expectancy)'], palette='flare', orient='h')
plt.title('Top 10 Countries With Lowest Healthy Life Expectancy', fontsize=15)
plt.xlabel('Health (Life Expectancy)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.17)
# Out:
# (0.0, 0.17)

# %% [markdown]
# #### The above table and barplot help us to know that Sierra Leone country have lowest healthy life expectance.

# %% [markdown]
# ### Top 10 Countries With Highest Freedom To Make Life Choices

# %%
# Top 10 Countries With Highest Freedom To Make Life Choices

happy_2015_freedom_top10 = happy_2015.groupby('Country')['Freedom'].max().sort_values(ascending=False).head(10).reset_index()
happy_2015_freedom_top10.columns = ['Country','Freedom']
happy_2015_freedom_top10
# Out:
#                 Country  Freedom
# 0                Norway  0.66973
# 1           Switzerland  0.66557
# 2              Cambodia  0.66246
# 3                Sweden  0.65980
# 4            Uzbekistan  0.65821
# 5             Australia  0.65124
# 6               Denmark  0.64938
# 7               Finland  0.64169
# 8  United Arab Emirates  0.64157
# 9                 Qatar  0.64040

# %%
# visualization top 10 highest freedom

plt.figure(figsize=(10,7))
sns.barplot(y=happy_2015_freedom_top10['Country'], x=happy_2015_freedom_top10['Freedom'], palette='copper', orient='h')
plt.title('Top 10 Countries With Highest Freedom To Make Life Choices', fontsize=15)
plt.xlabel('Freedom', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.65)
# Out:
# (0.0, 0.65)

# %% [markdown]
# #### The above table and barplot help us to know that Norway country have highest Freedom To Make Life Choices.

# %% [markdown]
# ### Top 10 Countries With Lowest Freedom To Make Life Choices

# %%
# Top 10 Countries With Lowest Freedom To Make Life Choices

happy_2015_freedom_bottom10 = happy_2015.groupby('Country')['Freedom'].max().sort_values(ascending=False).tail(10).reset_index()
happy_2015_freedom_bottom10.columns = ['Country','Freedom']
happy_2015_freedom_bottom10
# Out:
#                   Country  Freedom
# 0              Montenegro  0.18260
# 1                   Egypt  0.17288
# 2                   Syria  0.15684
# 3                Pakistan  0.12102
# 4                 Burundi  0.11850
# 5                  Angola  0.10384
# 6                   Sudan  0.10081
# 7  Bosnia and Herzegovina  0.09245
# 8                  Greece  0.07699
# 9                    Iraq  0.00000

# %%
# visualization bottom 10 freedom

plt.figure(figsize=(10,7))
sns.barplot(y=happy_2015_freedom_bottom10['Country'], x=happy_2015_freedom_bottom10['Freedom'], palette='copper', orient='h')
plt.title('Top 10 Countries With Lowest Freedom To Make Life Choices', fontsize=15)
plt.xlabel('Freedom', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.14)
# Out:
# (0.0, 0.14)

# %% [markdown]
# #### The above table and barplot help us to know that Iraq country have lowest Freedom To Make Life Choices.

# %% [markdown]
# ### Top 10 Countries With Highest Perceptions Of Corruption- Trust

# %%
# Top 10 Countries With Highest Perceptions Of Corruption- Trust 

happy_2015_Trust_top10 = happy_2015.groupby('Country')['Trust (Government Corruption)'].max().sort_values(ascending=False).head(10).reset_index()
happy_2015_Trust_top10.columns = ['Country','Trust (Government Corruption)']
happy_2015_Trust_top10
# Out:
#                 Country  Trust (Government Corruption)
# 0                Rwanda                        0.55191
# 1                 Qatar                        0.52208
# 2             Singapore                        0.49210
# 3               Denmark                        0.48357
# 4                Sweden                        0.43844
# 5           New Zealand                        0.42922
# 6           Switzerland                        0.41978
# 7               Finland                        0.41372
# 8     Somaliland region                        0.39928
# 9  United Arab Emirates                        0.38583

# %%
# visualization highest 10 Trust

plt.figure(figsize=(10,7))
sns.barplot(y=happy_2015_Trust_top10['Country'], x=happy_2015_Trust_top10['Trust (Government Corruption)'], palette='cividis', orient='h')
plt.title('Top 10 Countries With Highest Perceptions Of Corruption- Trust', fontsize=15)
plt.xlabel('Perception Of Corruption', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.6)
# Out:
# (0.0, 0.6)

# %% [markdown]
# #### The above table and barplot help us to know that Rwanda country have highest Perceptions Of Corruption- Trust.

# %% [markdown]
# ### Top 10 Countries With Lowest Perceptions Of Corruption- Trust

# %%
# Top 10 Countries With Lowest Perceptions Of Corruption- Trust

happy_2015_trust_bottom10 = happy_2015.groupby('Country')['Trust (Government Corruption)'].max().sort_values(ascending=False).tail(10).reset_index()
happy_2015_trust_bottom10.columns = ['Country','Trust (Government Corruption)']
happy_2015_trust_bottom10
# Out:
#                   Country  Trust (Government Corruption)
# 0                 Jamaica                        0.02299
# 1                 Moldova                        0.01615
# 2                  Greece                        0.01397
# 3     Trinidad and Tobago                        0.01140
# 4                Portugal                        0.01078
# 5               Lithuania                        0.01031
# 6                Bulgaria                        0.00872
# 7                 Romania                        0.00649
# 8  Bosnia and Herzegovina                        0.00227
# 9               Indonesia                        0.00000

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy_2015_trust_bottom10['Country'], x=happy_2015_trust_bottom10['Trust (Government Corruption)'], palette='cividis', orient='h')
plt.title('Top 10 Countries With Lowest Perceptions Of Corruption- Trust', fontsize=15)
plt.xlabel('Trust (Government Corruption)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.03)
# Out:
# (0.0, 0.03)

# %% [markdown]
# #### The above table and barplot help us to know that Indonesia country have lowest Perceptions Of Corruption- Trust.

# %% [markdown]
# ### Top 10 Countries With Highest Generosity

# %%
# top 10 countries with highest generosity

happy_2015_gen_top10 = happy_2015.groupby('Country')['Generosity'].max().sort_values(ascending=False).head(10).reset_index()
happy_2015_gen_top10.columns = ['Country','Generosity']
happy_2015_gen_top10
# Out:
#              Country  Generosity
# 0            Myanmar     0.79588
# 1           Thailand     0.57630
# 2     United Kingdom     0.51912
# 3              Malta     0.51752
# 4          Indonesia     0.51535
# 5  Somaliland region     0.50318
# 6             Bhutan     0.47998
# 7        Netherlands     0.47610
# 8        New Zealand     0.47501
# 9              Syria     0.47179

# %%
# visualization top 10 countries with highest generosity

plt.figure(figsize=(10,7))
sns.barplot(y=happy_2015_gen_top10['Country'], x=happy_2015_gen_top10['Generosity'], palette='icefire', orient='h')
plt.title('Top 10 Countries With Highest Generosity', fontsize=15)
plt.xlabel('Generosity', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.9)
# Out:
# (0.0, 0.9)

# %% [markdown]
# #### The above table and barplot help us to know that Myanmar country have highest Generosity.

# %% [markdown]
# ### Top 10 Countries With Lowest Generosity

# %%
# Top 10 Countries With Lowest Generosity

happy_2015_gen_bottom10 = happy_2015.groupby('Country')['Generosity'].max().sort_values(ascending=False).tail(10).reset_index()
happy_2015_gen_bottom10.columns = ['Country','Generosity']
happy_2015_gen_bottom10
# Out:
#       Country  Generosity
# 0  Azerbaijan     0.07799
# 1     Morocco     0.07172
# 2       Gabon     0.06822
# 3     Tunisia     0.06431
# 4   Venezuela     0.05841
# 5     Georgia     0.05547
# 6     Croatia     0.05444
# 7   Lithuania     0.02641
# 8      Russia     0.00199
# 9      Greece     0.00000

# %%
# visualization Top 10 Countries With Lowest Generosity

plt.figure(figsize=(10,7))
sns.barplot(y=happy_2015_gen_bottom10['Country'], x=happy_2015_gen_bottom10['Generosity'], palette='icefire', orient='h')
plt.title('Top 10 Countries With Lowest Generosity', fontsize=15)
plt.xlabel('Generosity', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.07)
# Out:
# (0.0, 0.07)

# %% [markdown]
# #### The above table and barplot help us to know that Azerbaijan country have lowest Generosity.

# %% [markdown]
# ### Top 10 Countries With Highest Dystopia Residual

# %%
# Top 10 Countries With Highest Dystopia Residual

happy_2015_dystopia_top10 = happy_2015.groupby('Country')['Dystopia Residual'].max().sort_values(ascending=False).head(10).reset_index()
happy_2015_dystopia_top10.columns = ['Country','Dystopia Residual']
happy_2015_dystopia_top10
# Out:
#        Country  Dystopia Residual
# 0       Mexico            3.60214
# 1       Brazil            3.26001
# 2    Venezuela            3.19131
# 3   Costa Rica            3.17728
# 4      Moldova            3.10712
# 5     Pakistan            3.10709
# 6       Israel            3.08854
# 7   Mozambique            3.05137
# 8  El Salvador            3.03500
# 9      Nigeria            2.89319

# %%
# visualization top 10 Countries With Highest Dystopia Residual

plt.figure(figsize=(10,7))
sns.barplot(y=happy_2015_dystopia_top10['Country'], x=happy_2015_dystopia_top10['Dystopia Residual'], palette='Greens_r', orient='h')
plt.title('Top 10 Countries With Highest Dystopia Residual', fontsize=15)
plt.xlabel('Dystopia Residual', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 3.9)
# Out:
# (0.0, 3.9)

# %% [markdown]
# #### The above table and barplot help us to know that Mexico country have highest Dystopia Residual.

# %% [markdown]
# ### Top 10 Countries With Lowest Dystopia Residual

# %%
# Top 10 Countries With Lowest Dystopia Residual

happy_2015_dystopia_bottom10 = happy_2015.groupby('Country')['Dystopia Residual'].max().sort_values(ascending=False).tail(10).reset_index()
happy_2015_dystopia_bottom10.columns = ['Country','Dystopia Residual']
happy_2015_dystopia_bottom10
# Out:
#               Country  Dystopia Residual
# 0            Portugal            1.26462
# 1             Hungary            1.24074
# 2  Dominican Republic            1.21305
# 3               Gabon            0.99895
# 4            Cambodia            0.98195
# 5            Bulgaria            0.89991
# 6           Sri Lanka            0.67108
# 7              Rwanda            0.67042
# 8           Hong Kong            0.65429
# 9               Syria            0.32858

# %%
# Top 10 Countries With Lowest Dystopia Residual

plt.figure(figsize=(10,7))
sns.barplot(y=happy_2015_dystopia_bottom10['Country'], x=happy_2015_dystopia_bottom10['Dystopia Residual'], palette='Greens_r', orient='h')
plt.title('Top 10 Countries With Lowest Dystopia Residual', fontsize=15)
plt.xlabel('Dystopia Residual', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 1.6)
# Out:
# (0.0, 1.6)

# %% [markdown]
# #### The above table and barplot help us to know that Syria country have lowest Dystopia Residual.

# %% [markdown]
# ## Relationship between independent variable and dependent variables through scatter plot.

# %%
# scatter plots shown below

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(12, 6), sharey='row', sharex='row')

axes[0, 0].scatter(x=happy_2015['Economy (GDP per Capita)'], y=happy_2015['Happiness Score'], color="red")
axes[0, 0].set_xlabel('Economy (GDP per Capita)')
axes[0, 0].set_ylabel('Happiness Score')

axes[0, 1].scatter(x=happy_2015['Family'], y=happy_2015['Happiness Score'], color="red")
axes[0, 1].set_xlabel('Family')
axes[0, 1].set_ylabel('Happiness Score')

axes[1, 0].scatter(x=happy_2015['Health (Life Expectancy)'], y=happy_2015['Happiness Score'], color="red")
axes[1, 0].set_xlabel('Health (Life Expectancy)')
axes[1, 0].set_ylabel('Happiness Score')

axes[1, 1].scatter(x=happy_2015['Freedom'], y=happy_2015['Happiness Score'], color="red")
axes[1, 1].set_xlabel('Freedom')
axes[1, 1].set_ylabel('Happiness Score')

axes[2, 0].scatter(x=happy_2015['Trust (Government Corruption)'],y=happy_2015['Happiness Score'], color="green")
axes[2, 0].set_xlabel('Corruption')
axes[2, 0].set_ylabel('Happiness Score')

axes[2, 1].scatter(x=happy_2015['Generosity'], y=happy_2015['Happiness Score'], color="red")
axes[2, 1].set_xlabel('Generosity')
axes[2, 1].set_ylabel('Happiness Score')

fig.tight_layout()

# %% [markdown]
# ### From above scatter plot, we can see that, except Perception Of Corruption every other thing like Economy (GDP Per Capita), Family Social Support, Health (Life Expectancy), Freedom To Choose Thing & Generosity makes people happy.

# %%
# Dropping the unwanted columns

happy_2015.drop(['Country','Region','Happiness Rank','Standard Error'],axis=1,inplace=True)
happy_2015.head()
# Out:
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            7.587                   1.39651  1.34951
# 1            7.561                   1.30232  1.40223
# 2            7.527                   1.32548  1.36058
# 3            7.522                   1.45900  1.33095
# 4            7.427                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %% [markdown]
# # ML Prediction

# %%
# divide dataset into feature and label

y = happy_2015['Happiness Score']
x = happy_2015.drop(columns = ['Happiness Score'])

# %%
x
# Out:
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# 5                     1.29025  1.31826                   0.88911  0.64169
# 6                     1.32944  1.28017                   0.89284  0.61576
# 7                     1.33171  1.28907                   0.91087  0.65980
# 8                     1.25018  1.31967                   0.90837  0.63938
# 9                     1.33358  1.30923                   0.93156  0.65124
# 10                    1.22857  1.22393                   0.91387  0.41319
# 11                    0.95578  1.23788                   0.86027  0.63376
# 12                    1.33723  1.29704                   0.89042  0.62433
# 13                    1.02054  0.91451                   0.81444  0.48181
# 14                    1.39451  1.24711                   0.86179  0.54604
# 15                    0.98124  1.23287                   0.69702  0.49049
# 16                    1.56391  1.21963                   0.91894  0.61583
# 17                    1.33596  1.36948                   0.89533  0.61777
# 18                    1.30782  1.28566                   0.89667  0.58450
# 19                    1.42727  1.12575                   0.80925  0.64157
# 20                    1.26637  1.28548                   0.90943  0.59625
# 21                    1.36011  1.08182                   0.76276  0.63274
# 22                    1.04424  1.25596                   0.72052  0.42908
# 23                    1.52186  1.02000                   1.02525  0.54252
# 24                    1.06353  1.19850                   0.79661  0.54210
# 25                    1.32792  1.29937                   0.89186  0.61477
# 131    4.271
# 132    4.252
# 133    4.218
# 134    4.194
# 135    4.077
# 136    4.033
# 137    3.995
# 138    3.989
# 139    3.956
# 140    3.931
# 141    3.904
# 142    3.896
# 143    3.845
# 144    3.819
# 145    3.781
# 146    3.681
# 147    3.678
# 148    3.667
# 149    3.656
# 150    3.655
# 151    3.587
# 152    3.575
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, dtype: float64

# %%
# data scaling

Scaler = StandardScaler()
x_Scaled = Scaler.fit_transform(x)
x_Scaled
# Out:
# array([[ 1.36962124,  1.32028142,  1.26340809, ...,  2.30965159,
#          0.47103971,  0.75825809],
#        [ 1.13522625,  1.51445776,  1.28943383, ..., -0.01647953,
#          1.57585637,  1.09285682],
#        [ 1.19286069,  1.36105403,  0.99222882, ...,  2.8427738 ,
#          0.8242928 ,  0.71233526],
#        ...,
#        [-0.45524543, -1.90108634,  0.37219907, ...,  0.38141902,
#          1.85689094, -3.20843049],
#        [-2.06756644, -2.1184666 , -1.64964766, ..., -0.35771452,
#         -0.31694987, -0.48198451],
#        [-1.58633379, -3.13472485, -1.40412871, ..., -0.30180313,
#         -0.5581534 , -0.96361241]])

# %%
# training and test model

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=12)

# %% [markdown]
# ### I have used 30% of dataset for testing purpose and 70% for training.

# %% [markdown]
# # Decision Tree Model

# %%
# predicting the model through decision tree

from sklearn.tree import DecisionTreeRegressor
RTD = DecisionTreeRegressor(random_state = 12)
RTD.fit(x_train, y_train)
y_pred = RTD.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.7898565889836191

# %% [markdown]
# # LinearRegression

# %%
# predicting the model through LinearRegression

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
y_pred = reg.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.9999999291066163

# %% [markdown]
# # Random Forest Model

# %%
# predicting the model through RandomForest

from sklearn.ensemble import RandomForestRegressor

RFR = RandomForestRegressor(n_estimators=10,random_state = 12 )
RFR.fit(x_train, y_train)
y_pred=RFR.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.8757341441663942

# %% [markdown]
# # Support vector machine

# %%
# predicting the model through Support vector machine

from sklearn.svm import SVR

SVR_Reg = SVR(kernel = "rbf",degree=3, C=40)
SVR_Reg.fit(x_train, y_train)
y_pred = SVR_Reg.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.991293929305516

# %% [markdown]
# # Conclusion

# %% [markdown]
# #### GDP per capita is having highest impact on Happiness score.
#
# Family is second in the list to impact Happiness score.
#
# Healthy Life Expectancy is third in the list to impact Happiness score.
#
# Freedom is fourth in the list to impact Happiness score.
#
# Trust (Government Corruption)lies after Freedom to impact Happiness Score.
#
# Generosity is the least in the factors to impacts Happiness score
#
# Inference -
# 1. Decision Tree r2_score - 78.9%
# 2. LinearRegression r2_score - 99.9%
# 3. Random Forest r2_score - 87.5%
# 4. Support vector machine r2_score - 99.1%
#
# Hence, LinearRegression is best out of four models.
